# %%
import pandas_oracle.tools as pt # pandas의 oracle DB 연결하는 패키지
import os # 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
os.putenv('NLS_LANG', '.UTF8')
conn = pt.open_connection('../oracle\config.yml')

# %%
#x :서비스 타입
#y :연령대별 판매건수

query1 = '''
SELECT *
FROM(SELECT 
       S_TYPE,
       AVG(TS_TIME_0_6_AMT) TS_TIME_0_6_AMT,
       AVG(TS_TIME_6_11_AMT) TS_TIME_6_11_AMT,
       AVG(TS_TIME_11_14_AMT) TS_TIME_11_14_AMT,
       AVG(TS_TIME_14_17_AMT) TS_TIME_14_17_AMT,
       AVG(TS_TIME_17_21_AMT) TS_TIME_17_21_AMT,
       AVG(TS_TIME_21_24_AMT) TS_TIME_21_24_AMT,
       (AVG(TS_TIME_0_6_AMT)+AVG(TS_TIME_6_11_AMT)+AVG(TS_TIME_11_14_AMT)+AVG(TS_TIME_14_17_AMT)+AVG(TS_TIME_17_21_AMT)+AVG(TS_TIME_21_24_AMT))/6 SUMAVG
       
FROM TIME_AMT_ANALYSIS T1, 
     ASTORE T2, 
     ASERVICE T3 
WHERE (T1.S_CODE = T2.S_CODE)
      and (T1.SE_CODE = T3.SE_CODE)
      and T1.TS_QUARTER = 1
      
Group By S_TYPE
Order By SUMAVG DESC) a1
WHERE ROWNUM BETWEEN 1 AND 5
'''

# %%
#x :서비스 타입
#y :연령대별 판매건수

query2 = '''
SELECT *
FROM(SELECT 
       S_TYPE,
       AVG(TS_TIME_0_6_AMT) TS_TIME_0_6_AMT,
       AVG(TS_TIME_6_11_AMT) TS_TIME_6_11_AMT,
       AVG(TS_TIME_11_14_AMT) TS_TIME_11_14_AMT,
       AVG(TS_TIME_14_17_AMT) TS_TIME_14_17_AMT,
       AVG(TS_TIME_17_21_AMT) TS_TIME_17_21_AMT,
       AVG(TS_TIME_21_24_AMT) TS_TIME_21_24_AMT,
       (AVG(TS_TIME_0_6_AMT)+AVG(TS_TIME_6_11_AMT)+AVG(TS_TIME_11_14_AMT)+AVG(TS_TIME_14_17_AMT)+AVG(TS_TIME_17_21_AMT)+AVG(TS_TIME_21_24_AMT))/6 SUMAVG
       
FROM TIME_AMT_ANALYSIS T1, 
     ASTORE T2, 
     ASERVICE T3 
WHERE (T1.S_CODE = T2.S_CODE)
      and (T1.SE_CODE = T3.SE_CODE)
      and T1.TS_QUARTER = 2
      
Group By S_TYPE
Order By SUMAVG DESC) a1
WHERE ROWNUM BETWEEN 1 AND 5
'''

# %%
#x :서비스 타입
#y :연령대별 판매건수

query3 = '''
SELECT *
FROM(SELECT 
       S_TYPE,
       AVG(TS_TIME_0_6_AMT) TS_TIME_0_6_AMT,
       AVG(TS_TIME_6_11_AMT) TS_TIME_6_11_AMT,
       AVG(TS_TIME_11_14_AMT) TS_TIME_11_14_AMT,
       AVG(TS_TIME_14_17_AMT) TS_TIME_14_17_AMT,
       AVG(TS_TIME_17_21_AMT) TS_TIME_17_21_AMT,
       AVG(TS_TIME_21_24_AMT) TS_TIME_21_24_AMT,
       (AVG(TS_TIME_0_6_AMT)+AVG(TS_TIME_6_11_AMT)+AVG(TS_TIME_11_14_AMT)+AVG(TS_TIME_14_17_AMT)+AVG(TS_TIME_17_21_AMT)+AVG(TS_TIME_21_24_AMT))/6 SUMAVG
       
FROM TIME_AMT_ANALYSIS T1, 
     ASTORE T2, 
     ASERVICE T3 
WHERE (T1.S_CODE = T2.S_CODE)
      and (T1.SE_CODE = T3.SE_CODE)
      and T1.TS_QUARTER = 3
      
Group By S_TYPE
Order By SUMAVG DESC) a1
WHERE ROWNUM BETWEEN 1 AND 5
'''

# %%
#x :서비스 타입
#y :연령대별 판매건수

query4 = '''
SELECT *
FROM(SELECT 
       S_TYPE,
       AVG(TS_TIME_0_6_AMT) TS_TIME_0_6_AMT,
       AVG(TS_TIME_6_11_AMT) TS_TIME_6_11_AMT,
       AVG(TS_TIME_11_14_AMT) TS_TIME_11_14_AMT,
       AVG(TS_TIME_14_17_AMT) TS_TIME_14_17_AMT,
       AVG(TS_TIME_17_21_AMT) TS_TIME_17_21_AMT,
       AVG(TS_TIME_21_24_AMT) TS_TIME_21_24_AMT,
       (AVG(TS_TIME_0_6_AMT)+AVG(TS_TIME_6_11_AMT)+AVG(TS_TIME_11_14_AMT)+AVG(TS_TIME_14_17_AMT)+AVG(TS_TIME_17_21_AMT)+AVG(TS_TIME_21_24_AMT))/6 SUMAVG
       
FROM TIME_AMT_ANALYSIS T1, 
     ASTORE T2, 
     ASERVICE T3 
WHERE (T1.S_CODE = T2.S_CODE)
      and (T1.SE_CODE = T3.SE_CODE)
      and T1.TS_QUARTER = 4
      
Group By S_TYPE
Order By SUMAVG DESC) a1
WHERE ROWNUM BETWEEN 1 AND 5
'''

# %%
df_query1_age = pt.query_to_df(query1, conn, 1000000)
df_query2_age = pt.query_to_df(query2, conn, 1000000)
df_query3_age = pt.query_to_df(query3, conn, 1000000)
df_query4_age = pt.query_to_df(query4, conn, 1000000)
#쿼리의 결과를 데이터 프레임으로 변환해줌 . (쿼리, 오라클 연결객체, 결과를 가져오기 까지 시간)

# %%
fig = plt.figure()
fig = plt.figure(figsize=(16, 16)) 
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.bar(df_query1_age ['S_TYPE'], df_query1_age ['TS_TIME_0_6_AMT'], label='TS_TIME_0_6_AMT')
ax1.bar(df_query1_age ['S_TYPE'], df_query1_age ['TS_TIME_6_11_AMT'], label='TS_TIME_6_11_AMT' , bottom =  df_query1_age ['TS_TIME_0_6_AMT'] )
ax1.bar(df_query1_age ['S_TYPE'], df_query1_age ['TS_TIME_11_14_AMT'], label='TS_TIME_11_14_AMT' , bottom =  df_query1_age ['TS_TIME_0_6_AMT'] + df_query1_age ['TS_TIME_6_11_AMT'])
ax1.bar(df_query1_age ['S_TYPE'], df_query1_age ['TS_TIME_14_17_AMT'], label='TS_TIME_14_17_AMT' , bottom =  df_query1_age ['TS_TIME_0_6_AMT'] + df_query1_age ['TS_TIME_6_11_AMT'] + df_query1_age ['TS_TIME_11_14_AMT'])
ax1.bar(df_query1_age ['S_TYPE'], df_query1_age ['TS_TIME_17_21_AMT'], label='TS_TIME_17_21_AMT' , bottom =  df_query1_age ['TS_TIME_0_6_AMT'] + df_query1_age ['TS_TIME_6_11_AMT'] + df_query1_age ['TS_TIME_11_14_AMT']+df_query1_age ['TS_TIME_14_17_AMT'])
ax1.bar(df_query1_age ['S_TYPE'], df_query1_age ['TS_TIME_21_24_AMT'], label='TS_TIME_21_24_AMT' , bottom =  df_query1_age ['TS_TIME_0_6_AMT'] + df_query1_age ['TS_TIME_6_11_AMT'] + df_query1_age ['TS_TIME_11_14_AMT']+df_query1_age ['TS_TIME_14_17_AMT'] + df_query1_age ['TS_TIME_17_21_AMT'])
ax1.legend(loc='upper right')

ax1.set_title('1분기')
ax1.set_xlabel('업종')
ax1.set_ylabel('평균판매액')
               
ax2.bar(df_query2_age ['S_TYPE'], df_query2_age ['TS_TIME_0_6_AMT'], label='TS_TIME_0_6_AMT')
ax2.bar(df_query2_age ['S_TYPE'], df_query2_age ['TS_TIME_6_11_AMT'], label='TS_TIME_6_11_AMT' ,   bottom =  df_query2_age ['TS_TIME_0_6_AMT'] )
ax2.bar(df_query2_age ['S_TYPE'], df_query2_age ['TS_TIME_11_14_AMT'], label='TS_TIME_11_14_AMT' , bottom =  df_query2_age ['TS_TIME_0_6_AMT'] + df_query2_age ['TS_TIME_6_11_AMT'])
ax2.bar(df_query2_age ['S_TYPE'], df_query2_age ['TS_TIME_14_17_AMT'], label='TS_TIME_14_17_AMT' , bottom =  df_query2_age ['TS_TIME_0_6_AMT'] + df_query2_age ['TS_TIME_6_11_AMT'] + df_query2_age ['TS_TIME_11_14_AMT'])
ax2.bar(df_query2_age ['S_TYPE'], df_query2_age ['TS_TIME_17_21_AMT'], label='TS_TIME_17_21_AMT' , bottom =  df_query2_age ['TS_TIME_0_6_AMT'] + df_query2_age ['TS_TIME_6_11_AMT'] + df_query2_age ['TS_TIME_11_14_AMT']+df_query2_age ['TS_TIME_14_17_AMT'])
ax2.bar(df_query2_age ['S_TYPE'], df_query2_age ['TS_TIME_21_24_AMT'], label='TS_TIME_21_24_AMT' , bottom =  df_query2_age ['TS_TIME_0_6_AMT'] + df_query2_age ['TS_TIME_6_11_AMT'] + df_query2_age ['TS_TIME_11_14_AMT']+df_query2_age ['TS_TIME_14_17_AMT'] + df_query2_age ['TS_TIME_17_21_AMT'])
ax2.legend(loc='upper right')

ax2.set_title('2분기')
ax2.set_xlabel('업종')
ax2.set_ylabel('평균판매액')

ax3.bar(df_query3_age ['S_TYPE'], df_query3_age ['TS_TIME_0_6_AMT'],   label='TS_TIME_0_6_AMT')
ax3.bar(df_query3_age ['S_TYPE'], df_query3_age ['TS_TIME_6_11_AMT'],  label='TS_TIME_6_11_AMT'  , bottom =  df_query3_age ['TS_TIME_0_6_AMT'] )
ax3.bar(df_query3_age ['S_TYPE'], df_query3_age ['TS_TIME_11_14_AMT'], label='TS_TIME_11_14_AMT' , bottom =  df_query3_age ['TS_TIME_0_6_AMT'] + df_query3_age ['TS_TIME_6_11_AMT'])
ax3.bar(df_query3_age ['S_TYPE'], df_query3_age ['TS_TIME_14_17_AMT'], label='TS_TIME_14_17_AMT' , bottom =  df_query3_age ['TS_TIME_0_6_AMT'] + df_query3_age ['TS_TIME_6_11_AMT'] + df_query3_age ['TS_TIME_11_14_AMT'])
ax3.bar(df_query3_age ['S_TYPE'], df_query3_age ['TS_TIME_17_21_AMT'], label='TS_TIME_17_21_AMT' , bottom =  df_query3_age ['TS_TIME_0_6_AMT'] + df_query3_age ['TS_TIME_6_11_AMT'] + df_query3_age ['TS_TIME_11_14_AMT']+df_query3_age ['TS_TIME_14_17_AMT'])
ax3.bar(df_query3_age ['S_TYPE'], df_query3_age ['TS_TIME_21_24_AMT'], label='TS_TIME_21_24_AMT' , bottom =  df_query3_age ['TS_TIME_0_6_AMT'] + df_query3_age ['TS_TIME_6_11_AMT'] + df_query3_age ['TS_TIME_11_14_AMT']+df_query3_age ['TS_TIME_14_17_AMT'] + df_query3_age ['TS_TIME_17_21_AMT'])
ax3.legend(loc='upper right')

ax3.set_title('3분기')
ax3.set_xlabel('업종')
ax3.set_ylabel('평균판매액')


ax4.bar(df_query4_age ['S_TYPE'], df_query4_age ['TS_TIME_0_6_AMT'],   label='TS_TIME_0_6_AMT')
ax4.bar(df_query4_age ['S_TYPE'], df_query4_age ['TS_TIME_6_11_AMT'],  label='TS_TIME_6_11_AMT' ,  bottom =  df_query4_age ['TS_TIME_0_6_AMT'] )
ax4.bar(df_query4_age ['S_TYPE'], df_query4_age ['TS_TIME_11_14_AMT'], label='TS_TIME_11_14_AMT' , bottom =  df_query4_age ['TS_TIME_0_6_AMT'] + df_query4_age ['TS_TIME_6_11_AMT'])
ax4.bar(df_query4_age ['S_TYPE'], df_query4_age ['TS_TIME_14_17_AMT'], label='TS_TIME_14_17_AMT' , bottom =  df_query4_age ['TS_TIME_0_6_AMT'] + df_query4_age ['TS_TIME_6_11_AMT'] + df_query4_age ['TS_TIME_11_14_AMT'])
ax4.bar(df_query4_age ['S_TYPE'], df_query4_age ['TS_TIME_17_21_AMT'], label='TS_TIME_17_21_AMT' , bottom =  df_query4_age ['TS_TIME_0_6_AMT'] + df_query4_age ['TS_TIME_6_11_AMT'] + df_query4_age ['TS_TIME_11_14_AMT']+df_query4_age ['TS_TIME_14_17_AMT'])
ax4.bar(df_query4_age ['S_TYPE'], df_query4_age ['TS_TIME_21_24_AMT'], label='TS_TIME_21_24_AMT' , bottom =  df_query4_age ['TS_TIME_0_6_AMT'] + df_query4_age ['TS_TIME_6_11_AMT'] + df_query4_age ['TS_TIME_11_14_AMT']+df_query4_age ['TS_TIME_14_17_AMT'] + df_query4_age ['TS_TIME_17_21_AMT'])
ax4.legend(loc='upper right')

ax4.set_title('4분기')
ax4.set_xlabel('업종')
ax4.set_ylabel('평균판매액')
# Out:
# Text(0, 0.5, '평균판매액')
