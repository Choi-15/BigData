# %%
import pandas_oracle.tools as pt
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.putenv('NLS_LANG', '.UTF8')
conn = pt.open_connection('../oracle\config.yml')
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
#x :서비스 타입
#y :연령대별 판매건수

query1 = '''
SELECT *
FROM(SELECT 
        SE_NAME,
       AVG(TS_10_AMT) AMT10,
       AVG(TS_20_AMT) AMT20,
       AVG(TS_30_AMT) AMT30,
       AVG(TS_40_AMT) AMT40,
       AVG(TS_50_AMT) AMT50,
       AVG(TS_60UP_AMT) AMT60,
       (AVG(TS_10_AMT)+AVG(TS_20_AMT)+AVG(TS_30_AMT)+AVG(TS_40_AMT)+AVG(TS_50_AMT)+AVG(TS_60UP_AMT))/6 SUMAVG
       
FROM AGE_AMT_ANALYSIS T1, 
     ASTORE T2, 
     ASERVICE T3 
WHERE (T1.S_CODE = T2.S_CODE)
      and (T1.SE_CODE = T3.SE_CODE)
      and T1.TS_QUARTER = 1
      
Group By  SE_NAME
Order By SUMAVG DESC) a1
WHERE ROWNUM BETWEEN 1 AND 5
'''

# %%
#x :서비스 타입
#y :연령대별 판매건수

query2 = '''
SELECT *
FROM(SELECT 
        SE_NAME,
       AVG(TS_10_AMT) AMT10,
       AVG(TS_20_AMT) AMT20,
       AVG(TS_30_AMT) AMT30,
       AVG(TS_40_AMT) AMT40,
       AVG(TS_50_AMT) AMT50,
       AVG(TS_60UP_AMT) AMT60,
       (AVG(TS_10_AMT)+AVG(TS_20_AMT)+AVG(TS_30_AMT)+AVG(TS_40_AMT)+AVG(TS_50_AMT)+AVG(TS_60UP_AMT))/6 SUMAVG
       
FROM AGE_AMT_ANALYSIS T1, 
     ASTORE T2, 
     ASERVICE T3 
WHERE (T1.S_CODE = T2.S_CODE)
      and (T1.SE_CODE = T3.SE_CODE)
      and T1.TS_QUARTER = 2
      
Group By  SE_NAME
Order By SUMAVG DESC) a1
WHERE ROWNUM BETWEEN 1 AND 5
'''

# %%
#x :서비스 타입
#y :연령대별 판매건수

query3 = '''
SELECT *
FROM(SELECT
            SE_NAME,
       AVG(TS_10_AMT) AMT10,
       AVG(TS_20_AMT) AMT20,
       AVG(TS_30_AMT) AMT30,
       AVG(TS_40_AMT) AMT40,
       AVG(TS_50_AMT) AMT50,
       AVG(TS_60UP_AMT) AMT60,
       (AVG(TS_10_AMT)+AVG(TS_20_AMT)+AVG(TS_30_AMT)+AVG(TS_40_AMT)+AVG(TS_50_AMT)+AVG(TS_60UP_AMT))/6 SUMAVG
       
FROM AGE_AMT_ANALYSIS T1, 
     ASTORE T2, 
     ASERVICE T3 
WHERE (T1.S_CODE = T2.S_CODE)
      and (T1.SE_CODE = T3.SE_CODE)
      and T1.TS_QUARTER = 3
      
Group By  SE_NAME
Order By SUMAVG DESC) a1
WHERE ROWNUM BETWEEN 1 AND 5
'''

# %%
#x :서비스 타입
#y :연령대별 판매건수

query4 = '''
SELECT *
FROM(SELECT 
            SE_NAME,
       AVG(TS_10_AMT) AMT10,
       AVG(TS_20_AMT) AMT20,
       AVG(TS_30_AMT) AMT30,
       AVG(TS_40_AMT) AMT40,
       AVG(TS_50_AMT) AMT50,
       AVG(TS_60UP_AMT) AMT60,
       (AVG(TS_10_AMT)+AVG(TS_20_AMT)+AVG(TS_30_AMT)+AVG(TS_40_AMT)+AVG(TS_50_AMT)+AVG(TS_60UP_AMT))/6 SUMAVG
       
FROM AGE_AMT_ANALYSIS T1, 
     ASTORE T2, 
     ASERVICE T3 
WHERE (T1.S_CODE = T2.S_CODE)
      and (T1.SE_CODE = T3.SE_CODE)
      and T1.TS_QUARTER =4
      
Group By  SE_NAME
Order By SUMAVG DESC) a1
WHERE ROWNUM BETWEEN 1 AND 5
'''

# %%
df_query1_age = pt.query_to_df(query1, conn, 1000000)
df_query2_age = pt.query_to_df(query2, conn, 1000000)
df_query3_age = pt.query_to_df(query3, conn, 1000000)
df_query4_age = pt.query_to_df(query4, conn, 1000000)
#쿼리의 결과를 데이터 프레임으로 변환해줌 . (쿼리, 오라클 연결객체, 결과를 가져오기 까지 시간)

# %%
df_query1_age 
df_query2_age 
df_query3_age 
df_query4_age
# Out:
#    SE_NAME         AMT10         AMT20         AMT30         AMT40  \
# 0      편의점  4.138544e+06  6.060904e+07  5.714675e+07  3.963547e+07
# 1     일반의원  7.533658e+05  1.406603e+07  2.721418e+07  3.399742e+07
# 2     치과의원  2.725930e+05  9.808737e+06  1.842724e+07  2.852704e+07
# 3  의약·의료용품  5.000628e+05  1.103420e+07  2.128231e+07  2.673180e+07
# 4     슈퍼마켓  9.559308e+05  1.475464e+07  2.326883e+07  3.107958e+07
#
#           AMT50         AMT60        SUMAVG
# 0  2.119566e+07  8.186492e+06  3.181866e+07
# 1  3.372885e+07  3.241702e+07  2.369614e+07
# 2  3.457368e+07  3.727871e+07  2.148133e+07
# 3  2.901425e+07  3.746790e+07  2.100509e+07
# 4  2.759734e+07  1.972908e+07  1.956423e+07

# %%
fig = plt.figure()
fig = plt.figure(figsize=(16, 16)) 
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax1.bar(df_query1_age ['SE_NAME'], df_query1_age ['AMT10'], label='AMT10')
ax1.bar(df_query1_age ['SE_NAME'], df_query1_age ['AMT20'], label='AMT20' , bottom =  df_query1_age ['AMT10'] )
ax1.bar(df_query1_age ['SE_NAME'], df_query1_age ['AMT30'], label='AMT30' , bottom =  df_query1_age ['AMT10'] + df_query1_age ['AMT20'])
ax1.bar(df_query1_age ['SE_NAME'], df_query1_age ['AMT40'], label='AMT40' , bottom =  df_query1_age ['AMT10'] + df_query1_age ['AMT20'] + df_query1_age ['AMT30'])
ax1.bar(df_query1_age ['SE_NAME'], df_query1_age ['AMT50'], label='AMT50' , bottom =  df_query1_age ['AMT10'] + df_query1_age ['AMT20'] + df_query1_age ['AMT30']+df_query1_age ['AMT40'])
ax1.bar(df_query1_age ['SE_NAME'], df_query1_age ['AMT60'], label='AMT60' , bottom =  df_query1_age ['AMT10'] + df_query1_age ['AMT20'] + df_query1_age ['AMT30']+df_query1_age ['AMT40'] + df_query1_age ['AMT50'])
ax1.legend(loc='upper right')

ax1.set_title('1분기')
ax1.set_xlabel('업종')
ax1.set_ylabel('평균판매액')
               
ax2.bar(df_query2_age ['SE_NAME'], df_query2_age ['AMT10'], label='AMT10')
ax2.bar(df_query2_age ['SE_NAME'], df_query2_age ['AMT20'], label='AMT20' , bottom =  df_query2_age ['AMT10'] )
ax2.bar(df_query2_age ['SE_NAME'], df_query2_age ['AMT30'], label='AMT30' , bottom =  df_query2_age ['AMT10'] + df_query2_age ['AMT20'])
ax2.bar(df_query2_age ['SE_NAME'], df_query2_age ['AMT40'], label='AMT40' , bottom =  df_query2_age ['AMT10'] + df_query2_age ['AMT20'] + df_query2_age ['AMT30'])
ax2.bar(df_query2_age ['SE_NAME'], df_query2_age ['AMT50'], label='AMT50' , bottom =  df_query2_age ['AMT10'] + df_query2_age ['AMT20'] + df_query2_age ['AMT30']+df_query2_age ['AMT40'])
ax2.bar(df_query2_age ['SE_NAME'], df_query2_age ['AMT60'], label='AMT60' , bottom =  df_query2_age ['AMT10'] + df_query2_age ['AMT20'] + df_query2_age ['AMT30']+df_query2_age ['AMT40'] + df_query2_age ['AMT50'])
ax2.legend(loc='upper right')

ax2.set_title('2분기')
ax2.set_xlabel('업종')
ax2.set_ylabel('평균판매액')

ax3.bar(df_query3_age ['SE_NAME'], df_query3_age ['AMT10'], label='AMT10')
ax3.bar(df_query3_age ['SE_NAME'], df_query3_age ['AMT20'], label='AMT20' , bottom =  df_query3_age ['AMT10'] )
ax3.bar(df_query3_age ['SE_NAME'], df_query3_age ['AMT30'], label='AMT30' , bottom =  df_query3_age ['AMT10'] + df_query3_age ['AMT20'])
ax3.bar(df_query3_age ['SE_NAME'], df_query3_age ['AMT40'], label='AMT40' , bottom =  df_query3_age ['AMT10'] + df_query3_age ['AMT20'] + df_query3_age ['AMT30'])
ax3.bar(df_query3_age ['SE_NAME'], df_query3_age ['AMT50'], label='AMT50' , bottom =  df_query3_age ['AMT10'] + df_query3_age ['AMT20'] + df_query3_age ['AMT30']+df_query3_age ['AMT40'])
ax3.bar(df_query3_age ['SE_NAME'], df_query3_age ['AMT60'], label='AMT60' , bottom =  df_query3_age ['AMT10'] + df_query3_age ['AMT20'] + df_query3_age ['AMT30']+df_query3_age ['AMT40'] + df_query3_age ['AMT50'])
ax3.legend(loc='upper right')

ax3.set_title('3분기')
ax3.set_xlabel('업종')
ax3.set_ylabel('평균판매액')


ax4.bar(df_query4_age ['SE_NAME'], df_query4_age ['AMT10'], label='AMT10')
ax4.bar(df_query4_age ['SE_NAME'], df_query4_age ['AMT20'], label='AMT20' , bottom =  df_query4_age ['AMT10'] )
ax4.bar(df_query4_age ['SE_NAME'], df_query4_age ['AMT30'], label='AMT30' , bottom =  df_query4_age ['AMT10'] + df_query4_age ['AMT20'])
ax4.bar(df_query4_age ['SE_NAME'], df_query4_age ['AMT40'], label='AMT40' , bottom =  df_query4_age ['AMT10'] + df_query4_age ['AMT20'] + df_query4_age ['AMT30'])
ax4.bar(df_query4_age ['SE_NAME'], df_query4_age ['AMT50'], label='AMT50' , bottom =  df_query4_age ['AMT10'] + df_query4_age ['AMT20'] + df_query4_age ['AMT30']+df_query4_age ['AMT40'])
ax4.bar(df_query4_age ['SE_NAME'], df_query4_age ['AMT60'], label='AMT60' , bottom =  df_query4_age ['AMT10'] + df_query4_age ['AMT20'] + df_query4_age ['AMT30']+df_query4_age ['AMT40'] + df_query4_age ['AMT50'])
ax4.legend(loc='upper right')

ax4.set_title('4분기')
ax4.set_xlabel('업종')
ax4.set_ylabel('평균판매액')



fig

# %%
x :서비스 타입
y :시간별 판매액
# Out:
#   File "<ipython-input-98-edf2b3b46c17>", line 1
#     x :서비스 타입
#            ^
# SyntaxError: invalid syntax

# %%
query_1 = '''
SELECT *
FROM ( SELECT TS_QUARTER,
            SE_NAME,
        AVG(TS_TIME_0_6_NUM) AVG0,
        AVG(TS_TIME_6_11_NUM) AVG6,
        AVG(TS_TIME_11_14_NUM) AVG11,
        AVG(TS_TIME_14_17_NUM) AVG14,
        AVG(TS_TIME_17_21_NUM) AVG17,
        AVG(TS_TIME_21_24_NUM) AVG21,
        (AVG(TS_TIME_0_6_NUM)+AVG(TS_TIME_6_11_NUM)+AVG(TS_TIME_11_14_NUM)+AVG(TS_TIME_14_17_NUM)+AVG(TS_TIME_17_21_NUM)+AVG(TS_TIME_21_24_NUM))/6 AVGTIME
FROM TIME_NUM_ANALYSIS T1,
    ASTORE T2, 
    ASERVICE T3 
WHERE (T1.S_CODE = T2.S_CODE)
        And (T1.SE_CODE = T3.SE_CODE)
        and (T1.TS_QUARTER)
        
Group By TS_QUARTER, SE_NAME)
Order By AVGTIME DESC) a1
WHERE ROWNUM BETWEEN 1 AND 5

'''

# %%
query4 = '''
SELECT *
FROM(SELECT TS_QUARTER,
            SE_NAME,
       AVG(TS_10_AMT) AMT10,
       AVG(TS_20_AMT) AMT20,
       AVG(TS_30_AMT) AMT30,
       AVG(TS_40_AMT) AMT40,
       AVG(TS_50_AMT) AMT50,
       AVG(TS_60UP_AMT) AMT60,
       (AVG(TS_10_AMT)+AVG(TS_20_AMT)+AVG(TS_30_AMT)+AVG(TS_40_AMT)+AVG(TS_50_AMT)+AVG(TS_60UP_AMT))/6 AMTAVG
       
FROM AGE_AMT_ANALYSIS T1, 
     ASTORE T2, 
     ASERVICE T3 
WHERE (T1.S_CODE = T2.S_CODE)
      and (T1.SE_CODE = T3.SE_CODE)
      and T1.TS_QUARTER = 4
      
Group By TS_QUARTER, SE_NAME
Order By TS_QUARTER ) a1
WHERE ROWNUM BETWEEN 1 AND 5
Order By AMTAVG desc
'''

# %%
df_query1_time = pt.query_to_df(query_1, conn, 1000000)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-76-ed09bd271d61> in <module>
# ----> 1 df_query1_time = pt.query_to_df(query_1, conn, 1000000)
#
# c:\app\python38\lib\site-packages\pandas_oracle\tools.py in query_to_df(query, conn_db, arraysize)
#      56        cur.arraysize = arraysize
#      57     ## execute query
# ---> 58     cur.execute(query)
#      59     ## fetch all rows
#      60     r = [fix_lob(row) for row in cur]
#
# DatabaseError: ORA-00920: invalid relational operator

# %%
axes1.bar(df_analysis_gender1.SE_NAME, df_analysis_gender1.AMTMALE,label='AMTMALE') 

axes1.bar(df_analysis_gender1.SE_NAME, df_analysis_gender1.AMTFEMALE,label='AMTFEMALE')
axes1.legend(loc='upper right')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-8ba7575e4339> in <module>
# ----> 1 axes1.bar(df_analysis_gender1.SE_NAME, df_analysis_gender1.AMTMALE,label='AMTMALE')
#       2
#       3 axes1.bar(df_analysis_gender1.SE_NAME, df_analysis_gender1.AMTFEMALE,label='AMTFEMALE')
#       4 axes1.legend(loc='upper right')
#
# NameError: name 'axes1' is not defined

# %%
x :서비스 타입
y :시간별 판매액

# %%
df_query1_age_graph = pd.melt(df_query1_age, id_vars = ['SE_NAME'], value_vars=['AMT10', 'AMT20', 'AMT30', 'AMT40', 'AMT50','AMT60'])

# %%
df_query1_age_graph
# Out:
#    SE_NAME variable         value
# 0    가구·가전    AMT10  2.460512e+05
# 1      PC방    AMT10  5.322672e+06
# 2   건강보조식품    AMT10  1.022903e+05
# 3   가전제품수리    AMT10  7.934360e+04
# 4      네일숍    AMT10  4.359331e+04
# 5    가구·가전    AMT20  7.213082e+06
# 6      PC방    AMT20  3.734141e+07
# 7   건강보조식품    AMT20  3.701314e+06
# 8   가전제품수리    AMT20  1.421313e+06
# 9      네일숍    AMT20  3.471275e+06
# 10   가구·가전    AMT30  1.994265e+07
# 11     PC방    AMT30  8.313701e+06
# 12  건강보조식품    AMT30  7.458109e+06
# 13  가전제품수리    AMT30  4.796403e+06
# 14     네일숍    AMT30  5.212300e+06
# 15   가구·가전    AMT40  2.668148e+07
# 16     PC방    AMT40  2.615081e+06
# 17  건강보조식품    AMT40  1.560629e+07
# 18  가전제품수리    AMT40  5.412151e+06
# 19     네일숍    AMT40  3.084843e+06
# 20   가구·가전    AMT50  2.869753e+07
# 21     PC방    AMT50  2.102794e+06
# 22  건강보조식품    AMT50  1.376951e+07
# 23  가전제품수리    AMT50  5.818704e+06
# 24     네일숍    AMT50  1.870576e+06
# 25   가구·가전    AMT60  1.994535e+07
# ...

# %%
fig = plt.figure()
fig = plt.figure(figsize=(16, 16)) 
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
ax1.bar(['variable'], df_num_time_0_6['value'], label='SE_NAME')

# %%
ax1.bar(df_num_time_0_6['variable'], df_num_time_0_6['value'], label='SE_NAME')
# axes2.bar(df_num_time_0_6['SE_NAME'], df_num_time_0_6['value'], label='AVG6')
# axes3.bar(df_num_time_0_6['SE_NAME'], df_num_time_0_6['value'], label='AVG11')
# axes4.bar(df_num_time_0_6['SE_NAME'], df_num_time_0_6['value'], label='AVG14')

# fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0a81eb5647d5> in <module>
# ----> 1 ax1.bar(df_num_time_0_6['variable'], df_num_time_0_6['value'], label='SE_NAME')
#       2 # axes2.bar(df_num_time_0_6['SE_NAME'], df_num_time_0_6['value'], label='AVG6')
#       3 # axes3.bar(df_num_time_0_6['SE_NAME'], df_num_time_0_6['value'], label='AVG11')
#       4 # axes4.bar(df_num_time_0_6['SE_NAME'], df_num_time_0_6['value'], label='AVG14')
#       5
#
# NameError: name 'df_num_time_0_6' is not defined
